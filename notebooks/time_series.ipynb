# %%
import pandas as pd
# Import the function from the script that displays the time series analysis
from scripts.time_series_analysis import time_series_analysis

# %%
# Load datasets
togo_df = pd.read_csv('../src/data/togo-dapaong_qc.csv', parse_dates=['Timestamp'])
benin_df = pd.read_csv('../src/data/benin-malanville.csv', parse_dates=['Timestamp'])
sierraleone_df = pd.read_csv('../src/data/sierraleone-bumbuna.csv', parse_dates=['Timestamp'])

# %%
# Call the function for each dataset
time_series_analysis(togo_df, "Togo")
# Out:
# /home/besu/PycharmProjects/solar-radation-analysis/scripts/time_series_analysis.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data.resample('M').mean()

# %%
# Call the function for each dataset
time_series_analysis(benin_df, "Benin")
# Out:
# /home/besu/PycharmProjects/solar-radation-analysis/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/besu/PycharmProjects/solar-radation-analysis/scripts/time_series_analysis.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data.resample('M').mean()

# %%
# Call the function for each dataset
time_series_analysis(sierraleone_df, "Sierra Leone")
# Out:
# /home/besu/PycharmProjects/solar-radation-analysis/scripts/time_series_analysis.py:29: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data.resample('M').mean()
# /home/besu/PycharmProjects/solar-radation-analysis/.venv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
